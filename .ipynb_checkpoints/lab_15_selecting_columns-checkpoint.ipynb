# %% [markdown]
# ## Selecting Columns

# %%
import pandas as pd

# %%
hero = pd.read_pickle('hero.pkl')

# %%
hero['height']
# Out:
# 0      185
# 1      185
# 2      180
# 3      257
# 4      183
#       ...
# 532    155
# 533    175
# 534    183
# 535    165
# 536    305
# Name: height, Length: 537, dtype: int64

# %%
hero['name']
# Out:
# 0             Abin Sur
# 1         Adam Strange
# 2           Alan Scott
# 3                Amazo
# 4           Animal Man
#             ...
# 532               X-23
# 533              X-Man
# 534       Yellowjacket
# 535    Yellowjacket II
# 536               Ymir
# Name: name, Length: 537, dtype: string

# %%
type(hero['name'])
# Out:
# pandas.core.series.Series

# %%
hero['name'].head(5)
# Out:
# 0        Abin Sur
# 1    Adam Strange
# 2      Alan Scott
# 3           Amazo
# 4      Animal Man
# Name: name, dtype: string

# %%
hero['name'].shape
# Out:
# (537,)

# %%
## Can use this method to call a column but isn't the most widly accepted version. hero['height'] is
hero.height
# Out:
# 0      185
# 1      185
# 2      180
# 3      257
# 4      183
#       ...
# 532    155
# 533    175
# 534    183
# 535    165
# 536    305
# Name: height, Length: 537, dtype: int64

# %%
hero[['name','weight','height']]
# Out:
#                 name  weight  height
# 0           Abin Sur    90.0     185
# 1       Adam Strange    88.0     185
# 2         Alan Scott    90.0     180
# 3              Amazo   173.0     257
# 4         Animal Man    83.0     183
# ..               ...     ...     ...
# 532             X-23    50.0     155
# 533            X-Man    61.0     175
# 534     Yellowjacket    83.0     183
# 535  Yellowjacket II    52.0     165
# 536             Ymir   -99.0     305
#
# [537 rows x 3 columns]

# %%
type(hero[['name','weight','height']])
# Out:
# pandas.core.frame.DataFrame

# %%
# Select all number columns
hero.select_dtypes(include = 'number')
# Out:
#      height  weight
# 0       185    90.0
# 1       185    88.0
# 2       180    90.0
# 3       257   173.0
# 4       183    83.0
# ..      ...     ...
# 532     155    50.0
# 533     175    61.0
# 534     183    83.0
# 535     165    52.0
# 536     305   -99.0
#
# [537 rows x 2 columns]

# %%
# Select all non-number column types
hero.select_dtypes(exclude = 'number')
# Out:
#                 name  gender eye color            race        hair color  \
# 0           Abin Sur    Male      blue         Ungaran           No Hair
# 1       Adam Strange    Male      blue           Human             Blond
# 2         Alan Scott    Male      blue               -             Blond
# 3              Amazo    Male       red         Android                 -
# 4         Animal Man    Male      blue           Human             Blond
# ..               ...     ...       ...             ...               ...
# 532             X-23  Female     green  Mutant / Clone             Black
# 533            X-Man    Male      blue               -             Brown
# 534     Yellowjacket    Male      blue           Human             Blond
# 535  Yellowjacket II  Female      blue           Human  Strawberry Blond
# 536             Ymir    Male     white     Frost Giant           No Hair
#
#          publisher alignment       hero names  agility  accelerated healing  \
# ...

# %%
## Selects only ints and category columns
hero.select_dtypes(include=['int64','category'])
# Out:
#      gender  height alignment
# 0      Male     185      good
# 1      Male     185      good
# 2      Male     180      good
# 3      Male     257       bad
# 4      Male     183      good
# ..      ...     ...       ...
# 532  Female     155      good
# 533    Male     175      good
# 534    Male     183      good
# 535  Female     165      good
# 536    Male     305      good
#
# [537 rows x 3 columns]

# %%
hero.select_dtypes(include=['int64','category']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537 entries, 0 to 536
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   gender     537 non-null    category
#  1   height     537 non-null    int64
#  2   alignment  537 non-null    category
# dtypes: category(2), int64(1)
# memory usage: 5.7 KB
